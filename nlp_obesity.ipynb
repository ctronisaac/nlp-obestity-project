# %% [markdown]
# <a href="https://colab.research.google.com/github/ctronisaac/nlp-obestity-project/blob/main/nlp_obesity.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#!pip install spacy
#this is not necessary because it is already installed in collabra

# %%
#not sure this is needed
#!python -m spacy download en_core_web_sm

# %%
import spacy
from spacy.matcher import PhraseMatcher

# %%
nlp = spacy.load("en_core_web_sm")

# %%
# !pip install tika
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for tika: filename=tika-2.6.0-py3-none-any.whl size=32621 sha256=40a06cbe90dfea8e3a4246490f744cecb9bf9d1af9793d6a4562892daa6a3830
#   Stored in directory: /root/.cache/pip/wheels/5f/71/c7/b757709531121b1700cffda5b6b0d4aad095fb507ec84316d0
# Successfully built tika
# ...

# %%
from tika import parser

# %% [markdown]
# #reminder to load documents - collabra does not save them

# %%
import re

# %%
def remove_URL(sample):
    """Remove URLs from a sample string"""
    return re.sub(r"http\S+", "", sample)

# %%
def print_sentence (sentence):
  sent = remove_URL(sentence.text.strip())
  sent = remove_URL(sent)
  while '\n\n' in sent:
    sent = sent.replace("\n\n", "\n")
  print ('***')
  print(sent)

# %%
def get_causes (filename):
  print ('==========')
  print ('==========')
  print ('Causes: ' + filename )
  print ('==========')
  print ('==========')
  raw = parser.from_file (filename)
  text = raw['content']
  #print(text)
  doc = nlp(text)
  special_words = ['obesity', 'cause']#, 'obese']
  for sentence in doc.sents:
    if all(word.lower() in sentence.text.lower() for word in special_words):
      print_sentence(sentence) #print(sentence.text.strip())

# %%
def get_solutions (filename):
  print ('==========')
  print ('==========')
  print ('Solutions: ' + filename )
  print ('==========')
  print ('==========')

  raw = parser.from_file (filename)
  text = raw['content']
  doc = nlp(text)
  special_words = ['obesity', 'solution']#, 'obese']
  for sentence in doc.sents:
    if all(word.lower() in sentence.text.lower() for word in special_words):
      print_sentence(sentence) #print(sentence.text.strip())      print(sentence.text)

# %%
def get_consequences (filename):
  print ('==========')
  print ('==========')
  print ('Consquences: ' + filename)
  print ('==========')
  print ('==========')
  raw = parser.from_file (filename)
  text = raw['content']
  doc = nlp(text)
  special_words = ['obesity', 'consequence']#, 'obese']
  for sentence in doc.sents:
    if all(word.lower() in sentence.text.lower() for word in special_words):
      print_sentence(sentence) #print(sentence.text.strip())      print(sentence.text)

# %%
files = ['/content/A systematic literature review on obesity -  Understanding the causes & consequences of obesity.pdf',
         '/content/Causes of obesity - a review.pdf',
         '/content/Effect of High Intensity Intermittent Training and Diet.pdf',
         '/content/Humans against Obesity - Who Will Win.pdf',
         '/content/Obesity pandemic causes, consequence solution.pdf',
         '/content/The relationship of Leptin, Exercie and Dietary Habits.pdf'
         ]
for file in files: #file = '/content/Obesity pandemic causes, consequence solution.pdf'
  get_causes(file)
  get_consequences(file)
  get_solutions(file)
# Out:
# ...
# Causes: /content/A systematic literature review on obesity -  Understanding the causes & consequences of obesity.pdf
# ...
# ***
# A systematic literature review on obesity: Understanding the causes & consequences of obesity and reviewing various machine learning approaches used to predict obesity
# Computers in Biology and Medicine 136 (2021)
# ***
# A systematic literature review on obesity: Understanding the causes &
# consequences of obesity and reviewing various machine learning
# approaches used to predict obesity
# Mahmood Safaei a, Elankovan A. Sundararajan a,*, Maha Driss b,c, Wadii Boulila b,c,
# Azrulhizam Shapi’i d
# a Centre for Software Technology and Management, Faculty of Information Science and Technology, Universiti Kebangsaan Malaysia (UKM), Bangi, 43600, Selangor,
# ***
# Therefore, the machine learning approach is a promising solution to early predictions of obesity and the
# ...

# %%
# Out:
# Consquences: /content/Obesity pandemic causes, consequence solution.pdf
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Obesity pandemic: causes, consequences, and solutions-but do we have the will?
#
#
#
# Obesity pandemic: causes,
# consequences, and solutions—but
# do we have the will?
#
#
# The numerous health consequences of obesity are discussed.
# Obesity causes, consequences, and solutions.
# THE HEALTH CONSEQUENCES OF OBESITY
# Many chronic illnesses and conditions are directly caused or
# adversely affected by obesity.
# Congestive heart failure,
# angina, and myocardial infarction are common
# consequences of obesity, and a significantly elevated BMI
# increases the risk of a fatal myocardial infarction (40).
#
# 839
#
# http://refhub.elsevier.com/S0015-0282(17)30223-6/sref17
# http://refhub.elsevier.com/S0015-0282(17)30223-6/sref17
# http://refhub.elsevier.com/S0015-0282(17)30223-6/sref17
# ...

# %%
# Out:
# Solutions: /content/Obesity pandemic causes, consequence solution.pdf
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Obesity pandemic: causes, consequences, and solutions-but do we have the will?
#
#
#
# Obesity pandemic: causes,
# consequences, and solutions—but
# do we have the will?
#
#
# Obesity causes, consequences, and solutions.
# POTENTIAL SOLUTIONS TO THE OBESITY
# CRISIS
# First, governmental agencies, stake-holding organizations,
# and the public at large must fully understand the magnitude
# and far-reaching effects of excess body weight and treat it as
# a true crisis at a level of threat greater than terrorism.
# 839
#
# http://refhub.elsevier.com/S0015-0282(17)30223-6/sref17
# http://refhub.elsevier.com/S0015-0282(17)30223-6/sref17
# http://refhub.elsevier.com/S0015-0282(17)30223-6/sref17
# http://refhub.elsevier.com/S0015-0282(17)30223-6/sref18
# ...
